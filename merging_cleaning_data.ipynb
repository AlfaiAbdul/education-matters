# %%
import pandas as pd
import csv

# %%
df1 = pd.read_csv('data1.csv')

# %%
df2 = pd.read_csv('data2.csv')

# %%
df1
# Out:
#         UNITID                                             INSTNM  \
# 0       100654                           Alabama A & M University
# 1       100663                University of Alabama at Birmingham
# 2       100690                                 Amridge University
# 3       100706                University of Alabama in Huntsville
# 4       100724                           Alabama State University
# 5       100751                          The University of Alabama
# 6       100760                  Central Alabama Community College
# 7       100812                            Athens State University
# 8       100830                    Auburn University at Montgomery
# 9       100858                                  Auburn University
# 10      100937                        Birmingham Southern College
# 11      101028             Chattahoochee Valley Community College
# 12      101073                          Concordia College Alabama
# ...

# %%
df2
# Out:
#         UNITID                                             INSTNM  \
# 0       100654                           Alabama A & M University
# 1       100663                University of Alabama at Birmingham
# 2       100690                                 Amridge University
# 3       100706                University of Alabama in Huntsville
# 4       100724                           Alabama State University
# 5       100751                          The University of Alabama
# 6       100760                  Central Alabama Community College
# 7       100812                            Athens State University
# 8       100830                    Auburn University at Montgomery
# 9       100858                                  Auburn University
# 10      100937                        Birmingham Southern College
# 11      101028             Chattahoochee Valley Community College
# 12      101073                          Concordia College Alabama
# ...

# %%
 data = pd.merge(df1, df2, on='UNITID', how='outer')

# %%
list(data)
# Out:
# ['UNITID',
#  'INSTNM_x',
#  'Percent of students over 23 at entry',
#  'PCT_WHITE',
#  'PCT_BLACK',
#  'PCT_ASIAN',
#  'PCT_HISPANIC',
#  'PCT_BORN_US',
#  'MEDIAN_HH_INC',
#  'POVERTY_RATE',
#  'UNEMP_RATE',
#  'LN_MEDIAN_HH_INC',
#  'Number of students not working and not enrolled 10 years after entry',
#  'Number of students working and not enrolled 10 years after entry',
#  'Mean earnings of students working and not enrolled 10 years after entry',
#  'Standard deviation of earnings of students working and not enrolled 10 years after entry',
#  'INSTNM_y',
#  'CITY',
#  'STABBR',
#  'ZIP',
#  'LATITUDE',
#  'LONGITUDE',
#  'ADM_RATE',
#  'ADM_RATE_ALL',
#  'SAT_AVG',
#  'PCIP01',
#  'PCIP03',
#  'PCIP04',
#  'PCIP05',
#  'PCIP09',
#  'PCIP10',
#  'PCIP11',
#  'PCIP12',
#  'PCIP13',
#  'PCIP14',
#  'PCIP15',
#  'PCIP16',
#  'PCIP19',
#  'PCIP22',
#  'PCIP23',
#  'PCIP24',
#  'PCIP25',
#  'PCIP26',
#  'PCIP27',
#  'PCIP29',
#  'PCIP30',
#  'PCIP31',
#  'PCIP38',
#  'PCIP39',
# ...

# %%
data
# Out:
#         UNITID                                           INSTNM_x  \
# 0       100654                           Alabama A & M University
# 1       100663                University of Alabama at Birmingham
# 2       100690                                 Amridge University
# 3       100706                University of Alabama in Huntsville
# 4       100724                           Alabama State University
# 5       100751                          The University of Alabama
# 6       100760                  Central Alabama Community College
# 7       100812                            Athens State University
# 8       100830                    Auburn University at Montgomery
# 9       100858                                  Auburn University
# 10      100937                        Birmingham Southern College
# 11      101028             Chattahoochee Valley Community College
# 12      101073                          Concordia College Alabama
# ...

# %%
clean_data = data.dropna(how='any')

# %%
clean_data
# Out:
#       UNITID                                           INSTNM_x  \
# 0     100654                           Alabama A & M University
# 1     100663                University of Alabama at Birmingham
# 3     100706                University of Alabama in Huntsville
# 4     100724                           Alabama State University
# 5     100751                          The University of Alabama
# 8     100830                    Auburn University at Montgomery
# 9     100858                                  Auburn University
# 10    100937                        Birmingham Southern College
# 16    101189                                Faulkner University
# 23    101435                                 Huntingdon College
# 24    101453                      Heritage Christian University
# 26    101480                      Jacksonville State University
# 30    101541                                     Judson College
# 32    101587                         University of West Alabama
# ...

# %%
clean_data.to_csv('master_data.csv')
